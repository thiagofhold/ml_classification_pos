# %%
import pandas as pd
import pandas_profiling

import statsmodels.formula.api as smf

# %%
base_fire = pd.read_csv('../output/fires_trt.csv')

# %%
base_fire.profile_report()
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
base_fire.head()
# Out:
#    year state    month  trt_month_year  trt_number trt_region trt_estacoes
# 0  1998  Acre  Janeiro  Janeiro - 1998           0      Norte        Verao
# 1  1999  Acre  Janeiro  Janeiro - 1999           0      Norte        Verao
# 2  2000  Acre  Janeiro  Janeiro - 2000           0      Norte        Verao
# 3  2001  Acre  Janeiro  Janeiro - 2001           0      Norte        Verao
# 4  2002  Acre  Janeiro  Janeiro - 2002           0      Norte        Verao

# %%
model = smf.ols(formula='trt_number ~ trt_region + trt_estacoes', data=base_fire).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             trt_number   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     34.69
# Date:                Tue, 01 Oct 2019   Prob (F-statistic):           7.94e-48
# Time:                        00:08:52   Log-Likelihood:                -1138.6
# No. Observations:                6454   AIC:                             2293.
# Df Residuals:                    6446   BIC:                             2347.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# ...
